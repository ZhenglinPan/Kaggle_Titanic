# %%
import numpy as np
from matplotlib import pyplot as plt

a = np.array([3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]).reshape(-1, 1)
b = np.array([2, 7, 1, 8, 2, 8, 1, 8, 2, 8, 4]).reshape(-1, 1)
c = np.array([1, 1, 2, 3, 5, 8, 11, 13, 17, 19]).reshape(-1, 1)
d = np.array([1, 9, 9, 9, 0, 9, 1, 3, 4, 2]).reshape(-1, 1)

fig = plt.figure(figsize=(8, 3), dpi=100)

plt.subplot(121)
plt.plot(a, color="orange", label="train loss")
plt.plot(b, color="royalblue", label="val loss")
plt.legend()

plt.subplot(122)
plt.plot(c, color="pink", label="train loss", )
plt.plot(d, color="purple", label="val loss")
plt.legend()

plt.show()
